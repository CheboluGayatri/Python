# %% [markdown]
# <a href="https://colab.research.google.com/github/CheboluGayatri/Python/blob/main/python_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Variable**
# which stores the values

# %%
x=10
print("x value :", x)
print(type(x))
# Out:
# x value : 10
# <class 'int'>

# %% [markdown]
# **declaration**
# python is implicit that declare automaticallly based on input

# %%
name="heamanth"
print("names value :",name)
print(type(name))
# Out:
# names value : heamanth
# <class 'str'>

# %% [markdown]
# **Assign**
# assign single value to multiple variables and multiple values at a time

# %%
a=b=c=5
print(a,b,c)
d,e,f=6,7,8
print(d,e,f)
# Out:
# 5 5 5
# 6 7 8

# %% [markdown]
# **python standard data types**
#
# -> In python we have six types of data types they are
# **1.Number**
# **2.string**
# **3.Tuple**
# **4.List**
# **5.Set**
# **6.Dictionary**

# %% [markdown]
# **1.Number data type**
# Number datatype stores numeric values,Numeric objects are mutable,Means when an object is created its value can be changed

# %%
a=200
b=400
print(a)
print(b)
#change variable values
a=500
b=900
print(a)
print(b)
#delete variables
del a
#print(a) it show error because a is deleted
# Out:
# 200
# 400
# 500
# 900

# %%
a=100 #a,b,c are variables and #100,200 are values ,c indicate operatiors like arthematic
b=200
c=a+b
print(c) # operator is collection of operands
#c ->operand
#= ->operator
#a ->operand
#b->operand
c=100, 200 #parameters
#passing a value to an operand is called parameter
# Out:
# 300

# %% [markdown]
# **Python Numerical data types**
# ->python support different data types they are 1.Int, 2.Long() only python 2.x version it is availble removed(deprecated) in 3.x version
# 3.float,4.complex

# %% [markdown]
# **1.Int**

# %%
x=10
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
a=0.345
print(a)
print(type(a))
# Out:
# 0.345
# <class 'float'>

# %%
y=complex(1,2)
print(y)
print(type(y))
# Out:
# (1+2j)
# <class 'complex'>

# %% [markdown]
# **Python Literals**
#
# **1.Binary Literals**
# by adding bin function decimal value convert into binary number it give output as 0b Prefix

# %%
x=bin(64)
print(x)
x=0b1000000
print(x)
# Out:
# 0b1000000
# 64

# %% [markdown]
# **2.octal Literals**
# convert any integer to octal number by adding oct it give outpot as 0o is Prefix

# %%
a=oct(8)
print(a)
# Out:
# 0o10

# %%
a=0o10
print(a)
# Out:
# 8

# %% [markdown]
# **Hexa-Deciaml Literals**
#
# we use predefined function as hex

# %%
x=hex(19)
print(x)
x=0x13
print(x) #divide by 16
# Out:
# 0x13
# 19
